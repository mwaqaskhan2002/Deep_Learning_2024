# %% [markdown]
# ## Assignment 3
#
# This dataset was built with the purpose of helping students in shortlisting universities with their profiles. The predicted output gives them a fair idea about their chances for a particular university.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

from sklearn.preprocessing import StandardScaler

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
df = pd.read_csv('Admission_Predict.csv')
df.head()
# Out:
#    Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0           1        337          118                  4  4.5   4.5  9.65
# 1           2        324          107                  4  4.0   4.5  8.87
# 2           3        316          104                  3  3.0   3.5  8.00
# 3           4        322          110                  3  3.5   2.5  8.67
# 4           5        314          103                  2  2.0   3.0  8.21
#
#    Research  Chance of Admit
# 0         1              0.92
# 1         1              0.76
# 2         1              0.72
# 3         1              0.80
# 4         0              0.65

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Serial No.         400 non-null    int64
#  1   GRE Score          400 non-null    int64
#  2   TOEFL Score        400 non-null    int64
#  3   University Rating  400 non-null    int64
#  4   SOP                400 non-null    float64
#  5   LOR                400 non-null    float64
#  6   CGPA               400 non-null    float64
#  7   Research           400 non-null    int64
#  8   Chance of Admit    400 non-null    float64
# dtypes: float64(4), int64(5)
# memory usage: 28.2 KB

# %%
df.columns = df.columns.str.strip()
x = df.drop(["Chance of Admit", "Serial No."], axis=1)
y = df["Chance of Admit"]

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
scaler = StandardScaler()
x_train_scaled = scaler.fit_transform(x_train)
x_test_scaled = scaler.transform(x_test)

# %%
lr_model = LinearRegression()
lr_model.fit(x_train_scaled, y_train)

y_pred = lr_model.predict(x_test_scaled)
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(f'MSE:{mse:.2f}')
print(f'R-Squared: {r2:.2f}')
# Out:
# MSE:0.00
# R-Squared: 0.82

# %%
# Create a model
model = Sequential()

# Add the first layer
model.add(Dense(64, activation='relu', input_shape=(7,)))

# Add the second layer
model.add(Dense(64, activation='relu'))

# Add the output layer
model.add(Dense(1))

# Compile the model
model.compile(optimizer='adam',
              loss='mean_squared_error',
              metrics=['mean_squared_error'])

print(model.summary())
# Out:
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_21 (Dense)            (None, 64)                512
#
#  dense_22 (Dense)            (None, 64)                4160
#
#  dense_23 (Dense)            (None, 1)                 65
#
# =================================================================
# Total params: 4737 (18.50 KB)
# Trainable params: 4737 (18.50 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None

# %%
history = model.fit(x_train, y_train, epochs=50, validation_split=0.2, verbose=2)
# Out:
# Epoch 1/50
# 8/8 - 1s - loss: 514.2725 - mean_squared_error: 514.2725 - val_loss: 231.6940 - val_mean_squared_error: 231.6940 - 1s/epoch - 171ms/step
# Epoch 2/50
# 8/8 - 0s - loss: 215.3536 - mean_squared_error: 215.3536 - val_loss: 24.1154 - val_mean_squared_error: 24.1154 - 90ms/epoch - 11ms/step
# Epoch 3/50
# 8/8 - 0s - loss: 33.0489 - mean_squared_error: 33.0489 - val_loss: 74.9620 - val_mean_squared_error: 74.9620 - 91ms/epoch - 11ms/step
# Epoch 4/50
# 8/8 - 0s - loss: 31.6184 - mean_squared_error: 31.6184 - val_loss: 3.3516 - val_mean_squared_error: 3.3516 - 88ms/epoch - 11ms/step
# Epoch 5/50
# 8/8 - 0s - loss: 14.4857 - mean_squared_error: 14.4857 - val_loss: 7.9778 - val_mean_squared_error: 7.9778 - 93ms/epoch - 12ms/step
# Epoch 6/50
# 8/8 - 0s - loss: 3.0765 - mean_squared_error: 3.0765 - val_loss: 6.2731 - val_mean_squared_error: 6.2731 - 92ms/epoch - 12ms/step
# Epoch 7/50
# 8/8 - 0s - loss: 3.0399 - mean_squared_error: 3.0399 - val_loss: 0.4687 - val_mean_squared_error: 0.4687 - 98ms/epoch - 12ms/step
# Epoch 8/50
# 8/8 - 0s - loss: 1.3716 - mean_squared_error: 1.3716 - val_loss: 0.3748 - val_mean_squared_error: 0.3748 - 151ms/epoch - 19ms/step
# Epoch 9/50
# 8/8 - 0s - loss: 0.3573 - mean_squared_error: 0.3573 - val_loss: 0.5421 - val_mean_squared_error: 0.5421 - 131ms/epoch - 16ms/step
# Epoch 10/50
# 8/8 - 0s - loss: 0.2070 - mean_squared_error: 0.2070 - val_loss: 0.2730 - val_mean_squared_error: 0.2730 - 121ms/epoch - 15ms/step
# Epoch 11/50
# 8/8 - 0s - loss: 0.1384 - mean_squared_error: 0.1384 - val_loss: 0.0436 - val_mean_squared_error: 0.0436 - 123ms/epoch - 15ms/step
# Epoch 12/50
# 8/8 - 0s - loss: 0.0723 - mean_squared_error: 0.0723 - val_loss: 0.0305 - val_mean_squared_error: 0.0305 - 143ms/epoch - 18ms/step
# Epoch 13/50
# 8/8 - 0s - loss: 0.0457 - mean_squared_error: 0.0457 - val_loss: 0.0469 - val_mean_squared_error: 0.0469 - 143ms/epoch - 18ms/step
# Epoch 14/50
# 8/8 - 0s - loss: 0.0362 - mean_squared_error: 0.0362 - val_loss: 0.0337 - val_mean_squared_error: 0.0337 - 109ms/epoch - 14ms/step
# Epoch 15/50
# 8/8 - 0s - loss: 0.0298 - mean_squared_error: 0.0298 - val_loss: 0.0429 - val_mean_squared_error: 0.0429 - 71ms/epoch - 9ms/step
# Epoch 16/50
# 8/8 - 0s - loss: 0.0272 - mean_squared_error: 0.0272 - val_loss: 0.0304 - val_mean_squared_error: 0.0304 - 78ms/epoch - 10ms/step
# Epoch 17/50
# 8/8 - 0s - loss: 0.0263 - mean_squared_error: 0.0263 - val_loss: 0.0336 - val_mean_squared_error: 0.0336 - 86ms/epoch - 11ms/step
# Epoch 18/50
# 8/8 - 0s - loss: 0.0267 - mean_squared_error: 0.0267 - val_loss: 0.0302 - val_mean_squared_error: 0.0302 - 95ms/epoch - 12ms/step
# Epoch 19/50
# 8/8 - 0s - loss: 0.0263 - mean_squared_error: 0.0263 - val_loss: 0.0319 - val_mean_squared_error: 0.0319 - 86ms/epoch - 11ms/step
# Epoch 20/50
# 8/8 - 0s - loss: 0.0257 - mean_squared_error: 0.0257 - val_loss: 0.0306 - val_mean_squared_error: 0.0306 - 88ms/epoch - 11ms/step
# Epoch 21/50
# 8/8 - 0s - loss: 0.0252 - mean_squared_error: 0.0252 - val_loss: 0.0308 - val_mean_squared_error: 0.0308 - 91ms/epoch - 11ms/step
# Epoch 22/50
# 8/8 - 0s - loss: 0.0251 - mean_squared_error: 0.0251 - val_loss: 0.0308 - val_mean_squared_error: 0.0308 - 87ms/epoch - 11ms/step
# Epoch 23/50
# 8/8 - 0s - loss: 0.0250 - mean_squared_error: 0.0250 - val_loss: 0.0299 - val_mean_squared_error: 0.0299 - 97ms/epoch - 12ms/step
# Epoch 24/50
# 8/8 - 0s - loss: 0.0249 - mean_squared_error: 0.0249 - val_loss: 0.0314 - val_mean_squared_error: 0.0314 - 95ms/epoch - 12ms/step
# Epoch 25/50
# 8/8 - 0s - loss: 0.0248 - mean_squared_error: 0.0248 - val_loss: 0.0303 - val_mean_squared_error: 0.0303 - 87ms/epoch - 11ms/step
# Epoch 26/50
# 8/8 - 0s - loss: 0.0247 - mean_squared_error: 0.0247 - val_loss: 0.0302 - val_mean_squared_error: 0.0302 - 82ms/epoch - 10ms/step
# Epoch 27/50
# 8/8 - 0s - loss: 0.0249 - mean_squared_error: 0.0249 - val_loss: 0.0296 - val_mean_squared_error: 0.0296 - 75ms/epoch - 9ms/step
# Epoch 28/50
# 8/8 - 0s - loss: 0.0245 - mean_squared_error: 0.0245 - val_loss: 0.0311 - val_mean_squared_error: 0.0311 - 74ms/epoch - 9ms/step
# Epoch 29/50
# 8/8 - 0s - loss: 0.0246 - mean_squared_error: 0.0246 - val_loss: 0.0296 - val_mean_squared_error: 0.0296 - 99ms/epoch - 12ms/step
# Epoch 30/50
# 8/8 - 0s - loss: 0.0246 - mean_squared_error: 0.0246 - val_loss: 0.0293 - val_mean_squared_error: 0.0293 - 100ms/epoch - 13ms/step
# Epoch 31/50
# 8/8 - 0s - loss: 0.0244 - mean_squared_error: 0.0244 - val_loss: 0.0297 - val_mean_squared_error: 0.0297 - 152ms/epoch - 19ms/step
# Epoch 32/50
# 8/8 - 0s - loss: 0.0241 - mean_squared_error: 0.0241 - val_loss: 0.0293 - val_mean_squared_error: 0.0293 - 143ms/epoch - 18ms/step
# Epoch 33/50
# 8/8 - 0s - loss: 0.0244 - mean_squared_error: 0.0244 - val_loss: 0.0325 - val_mean_squared_error: 0.0325 - 163ms/epoch - 20ms/step
# Epoch 34/50
# 8/8 - 0s - loss: 0.0241 - mean_squared_error: 0.0241 - val_loss: 0.0285 - val_mean_squared_error: 0.0285 - 109ms/epoch - 14ms/step
# Epoch 35/50
# 8/8 - 0s - loss: 0.0238 - mean_squared_error: 0.0238 - val_loss: 0.0299 - val_mean_squared_error: 0.0299 - 85ms/epoch - 11ms/step
# Epoch 36/50
# 8/8 - 0s - loss: 0.0238 - mean_squared_error: 0.0238 - val_loss: 0.0284 - val_mean_squared_error: 0.0284 - 83ms/epoch - 10ms/step
# Epoch 37/50
# 8/8 - 0s - loss: 0.0236 - mean_squared_error: 0.0236 - val_loss: 0.0307 - val_mean_squared_error: 0.0307 - 78ms/epoch - 10ms/step
# Epoch 38/50
# 8/8 - 0s - loss: 0.0237 - mean_squared_error: 0.0237 - val_loss: 0.0282 - val_mean_squared_error: 0.0282 - 86ms/epoch - 11ms/step
# Epoch 39/50
# 8/8 - 0s - loss: 0.0236 - mean_squared_error: 0.0236 - val_loss: 0.0315 - val_mean_squared_error: 0.0315 - 84ms/epoch - 10ms/step
# Epoch 40/50
# 8/8 - 0s - loss: 0.0233 - mean_squared_error: 0.0233 - val_loss: 0.0274 - val_mean_squared_error: 0.0274 - 83ms/epoch - 10ms/step
# Epoch 41/50
# 8/8 - 0s - loss: 0.0231 - mean_squared_error: 0.0231 - val_loss: 0.0294 - val_mean_squared_error: 0.0294 - 82ms/epoch - 10ms/step
# Epoch 42/50
# 8/8 - 0s - loss: 0.0231 - mean_squared_error: 0.0231 - val_loss: 0.0285 - val_mean_squared_error: 0.0285 - 85ms/epoch - 11ms/step
# Epoch 43/50
# 8/8 - 0s - loss: 0.0229 - mean_squared_error: 0.0229 - val_loss: 0.0278 - val_mean_squared_error: 0.0278 - 85ms/epoch - 11ms/step
# Epoch 44/50
# 8/8 - 0s - loss: 0.0225 - mean_squared_error: 0.0225 - val_loss: 0.0269 - val_mean_squared_error: 0.0269 - 93ms/epoch - 12ms/step
# Epoch 45/50
# 8/8 - 0s - loss: 0.0232 - mean_squared_error: 0.0232 - val_loss: 0.0267 - val_mean_squared_error: 0.0267 - 80ms/epoch - 10ms/step
# Epoch 46/50
# 8/8 - 0s - loss: 0.0229 - mean_squared_error: 0.0229 - val_loss: 0.0296 - val_mean_squared_error: 0.0296 - 86ms/epoch - 11ms/step
# Epoch 47/50
# 8/8 - 0s - loss: 0.0225 - mean_squared_error: 0.0225 - val_loss: 0.0261 - val_mean_squared_error: 0.0261 - 85ms/epoch - 11ms/step
# Epoch 48/50
# 8/8 - 0s - loss: 0.0219 - mean_squared_error: 0.0219 - val_loss: 0.0268 - val_mean_squared_error: 0.0268 - 80ms/epoch - 10ms/step
# Epoch 49/50
# 8/8 - 0s - loss: 0.0217 - mean_squared_error: 0.0217 - val_loss: 0.0264 - val_mean_squared_error: 0.0264 - 82ms/epoch - 10ms/step
# Epoch 50/50
# 8/8 - 0s - loss: 0.0213 - mean_squared_error: 0.0213 - val_loss: 0.0271 - val_mean_squared_error: 0.0271 - 77ms/epoch - 10ms/step
